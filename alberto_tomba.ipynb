# %%
from gettext import install
import pip

# %pip install requests beautifulsoup4 pandas openpyxl lxml selenium

# %%
# Alberto Tomba Wikipedia page

from bs4 import BeautifulSoup
import lxml
import requests
import pandas as pd
import time

# Set a descriptive User-Agent header
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

url = 'https://en.wikipedia.org/wiki/Alberto_Tomba'
response = requests.get(url, headers=headers)
response.raise_for_status()

soup = BeautifulSoup(response.text, 'lxml')

# Find the "World Cup results" heading
wcr_heading = soup.find('h2', string=lambda s: s and 'World Cup results' in s)

if wcr_heading:
    # Find the table that follows this heading
    table = wcr_heading.find_next('table')
    
    if table:
        # Extract table data
        rows = []
        for tr in table.find_all('tr'):
            cols = tr.find_all(['td', 'th'])
            row_data = [col.get_text(strip=True) for col in cols]
            if row_data:  # Only add non-empty rows
                rows.append(row_data)
        
        # Convert to DataFrame for better visualization
        df = pd.DataFrame(rows[1:], columns=rows[0])
        print(df)
        print(f"\nTotal rows: {len(df)}")
    else:
        print("Table not found")
else:
    print("World Cup results section not found")

# Export to XLSX
#df.to_excel('alberto_tomba_world_cup_results.xlsx', index=False)
